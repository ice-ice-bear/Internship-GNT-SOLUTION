# %% [markdown]
# * 자료출처
# https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1KB9011&vw_cd=MT_ZTITLE&list_id=J_20_6&seqNo=&lang_mode=ko&language=kor&obj_var_id=&itm_id=&conn_path=MT_ZTITLE

# %%
import pandas as pd
import numpy as np

# %%
df.shape
# Out:
# (433, 13)

# %%
df.head(10)
# Out:
#    시도별          건물연면적규모별         산업별      2019    2019.1     2019.2  \
# 0  시도별          건물연면적규모별         산업별  사업체수 (개)  종사자수 (명)  매출액 (백만원)
# 1   전국                 계     대형종합소매업       585     75104   38470212
# 2   전국                 계         백화점        97     12171   11038815
# 3   전국                 계       대형 마트       488     62933   27431397
# 4   전국                 계  기타 대형종합소매업         -         -          -
# 5   전국        6,600m² 미만     대형종합소매업        76      7169    3261570
# 6   전국        6,600m² 미만         백화점         6       653     777537
# 7   전국        6,600m² 미만       대형 마트        70      6516    2484033
# 8   전국        6,600m² 미만  기타 대형종합소매업         -         -          -
# 9   전국  6,600-9,900m² 미만     대형종합소매업        47      5099    2041801
#
#        2019.3      2019.4          2019.5     2019.6     2019.7      2019.8  \
# 0  영업비용 (백만원)  매출원가 (백만원)  판매비와 관리비 (백만원)  인건비 (백만원)  임차료 (백만원)  기타경비 (백만원)
# ...

# %%
department_store = df[df['업체별'] == '백화점']

# %%
department_store
# Out:
#       시도별  업체별  사업체수 (개) 종사자수 (명) 남자 (명) 여자 (명) 판매액계 (백만원) 전년하반기 (백만원)  \
# 1      전국  백화점      63.0    23450   8747  14703    2609644     1210253
# 4   서울특별시  백화점      25.0    13483   5567   7916    1738679      797350
# 7   부산광역시  백화점       8.0     1911    534   1377     121342       64036
# 10  대구광역시  백화점       4.0     2307    662   1645     260786      123700
# 13  인천광역시  백화점       2.0      491    215    276      40601       19816
# 16  광주광역시  백화점       4.0     1010    334    676      95975       48260
# 19  대전광역시  백화점       3.0      858    312    546      77466       35597
# 22    경기도  백화점       5.0      825    291    534      76556       30641
# 27   충청북도  백화점       2.0      266    100    166      25659       10214
# 30   충청남도  백화점       1.0        -      -      -          -           -
# 33   전라북도  백화점       1.0        -      -      -          -           -
# 36   전라남도  백화점       NaN        -      -      -          -           -
# ...
