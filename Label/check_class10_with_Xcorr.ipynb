# %%
import os

folder_path = 'C:/Users/GnTRnD/Desktop/temp_file/0306/03/left'
output_file = 'file_list.txt'

with open(output_file, 'w') as f:
    for filename in os.listdir(folder_path):
        try:
            with open(os.path.join(folder_path, filename), 'r') as file:
                for line in file:
                    values = line.split()
                    class_number = int(values[0])
                    x_coordinate = float(values[1])
                    if class_number == 1:
                        x_min = x_coordinate
                    elif class_number == 10:
                        if x_coordinate < x_min:
                            f.write(f"{filename}\n")
                            break
        except PermissionError:
            print(f"Permission denied: {filename}")

# %%
#check if pillar is larger than expected

import os

folder_path = '//schoolnas-work/schoolnas-work/seatbelt/aimmo_230323_labels/gnt_solution_output/gnt_solution_output/대왕판교선별이미지(221229_230110)/230103'
output_file = folder_path + './0.file_list.txt'

with open(output_file, 'w') as f:
    for filename in os.listdir(folder_path):
        if filename.endswith('.txt'):
            try:
                with open(os.path.join(folder_path, filename), 'r') as file:
                    for line in file:
                        try: 
                            values = line.split()
                            class_number = int(values[0])
                            x_coordinate = float(values[1])
                            y_coordinate = float(values[2])
                            width = float(values[3])
                            height = float(values[4])
                            if class_number == 1:
                                if width > 0.2:
                                    f.write(f"{filename}\n")
                                    break
                        except ValueError:
                            print(f"ValueError: {filename}")
                        
            except PermissionError:
                print(f"Permission denied: {filename}")
# Out:
# ValueError: classes.txt
# ValueError: classes.txt
# ValueError: classes.txt
# ValueError: classes.txt
# ValueError: classes.txt
# ValueError: classes.txt
# ValueError: classes.txt
# ValueError: classes.txt
# ValueError: classes.txt
# ValueError: classes.txt
# ValueError: classes.txt
# ValueError: classes.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 0.empty_files.txt
# ValueError: 1.double_labeled(2,3,8).txt
# ValueError: 1.double_labeled(2,3,8).txt
# ValueError: 2.double_labeled(4,5,9).txt
# ValueError: 2.double_labeled(4,5,9).txt
# ValueError: 2.double_labeled(4,5,9).txt
# ValueError: 2.double_labeled(4,5,9).txt
# ValueError: 2.double_labeled(4,5,9).txt
# ValueError: 2.double_labeled(4,5,9).txt
# ValueError: 2.double_labeled(4,5,9).txt
# ValueError: 2.double_labeled(4,5,9).txt
# ValueError: 2.double_labeled(4,5,9).txt
# ValueError: 2.double_labeled(4,5,9).txt

# %%
#check if pillar is larger than expected

import os

folder_path = 'path/to/folder'
output_file = folder_path + './class_file.txt'

with open(output_file, 'w') as f:
    for filename in os.listdir(folder_path):
        if filename.endswith('.txt'):
            try:
                with open(os.path.join(folder_path, filename), 'r') as file:
                    for line in file:
                        try: 
                            values = line.split()
                            class_number = int(values[0])
                            x_coordinate = float(values[1])
                            y_coordinate = float(values[2])
                            width = float(values[3])
                            height = float(values[4])
                            confidence = float(values[5])
                            if class_number == 1:
                                if width > 0.2:
                                    f.write(f"{filename}\n")
                                    break
                        except ValueError:
                            print(f"ValueError: {filename}")
                        
            except PermissionError:
                print(f"Permission denied: {filename}")
