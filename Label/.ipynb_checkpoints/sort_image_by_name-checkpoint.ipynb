# %%
#Only care about the file name not the file extension
import os
import shutil

image_folder = r'path/to/image_folder'
text_file = r'path/to/text_file'
output_folder = r'path/to/output_folder'

with open(text_file, 'r') as f:
    exclude_list = set(f.read().splitlines())

for root, dirs, files in os.walk(image_folder):
    for file in files:
        filename = os.path.splitext(file)[0] # get filename without extension
        if filename in exclude_list:
            image_path = os.path.join(root, file)
            output_path = os.path.join(output_folder, file)
            print('Moving file:', image_path, 'to', output_path)
            shutil.move(image_path, output_path)

# %%
#care both file name and file extension
#move image

import os
import shutil

image_folder = r'path/to/image_folder'
text_file = r'path/to/text_file'
output_folder = r'path/to/output_folder'

with open(text_file, 'r') as f:
    exclude_list = set(f.read().splitlines())

for root, dirs, files in os.walk(image_folder):
    for file in files:
        if file.endswith('.jpg') or file.endswith('.txt'):
            if file in exclude_list:
                image_path = os.path.join(root, file)
                output_path = os.path.join(output_folder, file)
                print('Moving image:', image_path, 'to', output_path)
                shutil.move(image_path, output_path)
# Out:
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\left1_230307_155132_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_155132_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\left1_230307_155326_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_155326_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\left1_230307_155355_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_155355_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\left1_230307_155710_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_155710_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\left1_230307_155740_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_155740_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\left1_230307_160541_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_160541_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\left1_230307_160746_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_160746_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\left1_230307_165838_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_165838_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\left1_230307_165955_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_165955_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\left1_230307_170008_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_170008_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\left1_230307_170737_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_170737_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\left1_230307_171101_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_171101_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\left1_230307_172135_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_172135_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\left1_230307_172449_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_172449_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\left1_230307_172847_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_172847_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_155132_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_155132_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_155326_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_155326_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_155355_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_155355_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_155710_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_155710_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_155740_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_155740_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_160541_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_160541_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_160746_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_160746_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_165838_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_165838_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_165955_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_165955_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_170008_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_170008_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_170737_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_170737_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_171101_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_171101_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_172135_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_172135_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_172449_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_172449_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_172847_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_172847_0.jpg
# Moving image: \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\애매한이미지\left1_230307_155232_0.jpg to \\schoolnas-work\schoolnas-work\seatbelt\seatbelt_label_03_06_added_230324_train_data\08_jj_230307_carnival_hdyoon_finish(재검수!!-않보이면제거할지결정필요)\운전석안보임\left1_230307_155232_0.jpg

# %%
#copy image

import os
import shutil

image_folder = r'C:\Users\GnTRnD\Desktop\LSR\yolov5_lsr\runs\detect\seatbelt_sh_jj_dwpg_kcity_aimmo_230227_checked_fin_230314_dwpg_230315_conf55_results\labels'
text_file = r'C:\Users\GnTRnD\Desktop\seatbelt_label\file_names.txt'
output_folder = r'\\schoolnas-work\schoolnas-work\seatbelt\dwpg_after_change_four_lights\230315_person05_person05seatbelt'

with open(text_file, 'r') as f:
    exclude_list = set(f.read().splitlines())

for root, dirs, files in os.walk(image_folder):
    for file in files:
        if file.endswith('.jpg') or file.endswith('.txt'):
            if file in exclude_list:
                image_path = os.path.join(root, file)
                output_path = os.path.join(output_folder, file)
                print('Copying image:', image_path, 'to', output_path)
                shutil.copy(image_path, output_path)
# Out:
# Copying image: C:\Users\GnTRnD\Desktop\LSR\yolov5_lsr\runs\detect\seatbelt_sh_jj_dwpg_kcity_aimmo_230227_checked_fin_230314_dwpg_230315_conf55_results\labels\left1_230315_135247_2.txt to \\schoolnas-work\schoolnas-work\seatbelt\dwpg_after_change_four_lights\230315_person05_person05seatbelt\left1_230315_135247_2.txt
# Copying image: C:\Users\GnTRnD\Desktop\LSR\yolov5_lsr\runs\detect\seatbelt_sh_jj_dwpg_kcity_aimmo_230227_checked_fin_230314_dwpg_230315_conf55_results\labels\left1_230315_151120_0.txt to \\schoolnas-work\schoolnas-work\seatbelt\dwpg_after_change_four_lights\230315_person05_person05seatbelt\left1_230315_151120_0.txt
# Copying image: C:\Users\GnTRnD\Desktop\LSR\yolov5_lsr\runs\detect\seatbelt_sh_jj_dwpg_kcity_aimmo_230227_checked_fin_230314_dwpg_230315_conf55_results\labels\left1_230315_160547_0.txt to \\schoolnas-work\schoolnas-work\seatbelt\dwpg_after_change_four_lights\230315_person05_person05seatbelt\left1_230315_160547_0.txt
# Copying image: C:\Users\GnTRnD\Desktop\LSR\yolov5_lsr\runs\detect\seatbelt_sh_jj_dwpg_kcity_aimmo_230227_checked_fin_230314_dwpg_230315_conf55_results\labels\left1_230315_160547_1.txt to \\schoolnas-work\schoolnas-work\seatbelt\dwpg_after_change_four_lights\230315_person05_person05seatbelt\left1_230315_160547_1.txt
# Copying image: C:\Users\GnTRnD\Desktop\LSR\yolov5_lsr\runs\detect\seatbelt_sh_jj_dwpg_kcity_aimmo_230227_checked_fin_230314_dwpg_230315_conf55_results\labels\left1_230315_171621_1.txt to \\schoolnas-work\schoolnas-work\seatbelt\dwpg_after_change_four_lights\230315_person05_person05seatbelt\left1_230315_171621_1.txt
# Copying image: C:\Users\GnTRnD\Desktop\LSR\yolov5_lsr\runs\detect\seatbelt_sh_jj_dwpg_kcity_aimmo_230227_checked_fin_230314_dwpg_230315_conf55_results\labels\left1_230315_171621_2.txt to \\schoolnas-work\schoolnas-work\seatbelt\dwpg_after_change_four_lights\230315_person05_person05seatbelt\left1_230315_171621_2.txt
# Copying image: C:\Users\GnTRnD\Desktop\LSR\yolov5_lsr\runs\detect\seatbelt_sh_jj_dwpg_kcity_aimmo_230227_checked_fin_230314_dwpg_230315_conf55_results\labels\right1_230315_074448_0.txt to \\schoolnas-work\schoolnas-work\seatbelt\dwpg_after_change_four_lights\230315_person05_person05seatbelt\right1_230315_074448_0.txt
# Copying image: C:\Users\GnTRnD\Desktop\LSR\yolov5_lsr\runs\detect\seatbelt_sh_jj_dwpg_kcity_aimmo_230227_checked_fin_230314_dwpg_230315_conf55_results\labels\right1_230315_142116_1.txt to \\schoolnas-work\schoolnas-work\seatbelt\dwpg_after_change_four_lights\230315_person05_person05seatbelt\right1_230315_142116_1.txt
# Copying image: C:\Users\GnTRnD\Desktop\LSR\yolov5_lsr\runs\detect\seatbelt_sh_jj_dwpg_kcity_aimmo_230227_checked_fin_230314_dwpg_230315_conf55_results\labels\right1_230315_171621_1.txt to \\schoolnas-work\schoolnas-work\seatbelt\dwpg_after_change_four_lights\230315_person05_person05seatbelt\right1_230315_171621_1.txt
# Copying image: C:\Users\GnTRnD\Desktop\LSR\yolov5_lsr\runs\detect\seatbelt_sh_jj_dwpg_kcity_aimmo_230227_checked_fin_230314_dwpg_230315_conf55_results\labels\right1_230315_194801_1.txt to \\schoolnas-work\schoolnas-work\seatbelt\dwpg_after_change_four_lights\230315_person05_person05seatbelt\right1_230315_194801_1.txt
# Copying image: C:\Users\GnTRnD\Desktop\LSR\yolov5_lsr\runs\detect\seatbelt_sh_jj_dwpg_kcity_aimmo_230227_checked_fin_230314_dwpg_230315_conf55_results\labels\right1_230315_194801_2.txt to \\schoolnas-work\schoolnas-work\seatbelt\dwpg_after_change_four_lights\230315_person05_person05seatbelt\right1_230315_194801_2.txt

# %%
#remove image

import os
import shutil

image_folder = r'//schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival'
text_file = r'C:/Users/GnTRnD/Desktop/remove_list.txt'

with open(text_file, 'r') as f:
    exclude_list = set(f.read().splitlines())

# # compare file extension
# for root, dirs, files in os.walk(image_folder):
#     for file in files:
#         if file.endswith('.jpg') or file.endswith('.txt'):
#             if file in exclude_list:
#                 image_path = os.path.join(root, file)
#                 print('The image has been deleted:', image_path)
#                 os.remove(image_path)
                         
#don't conpare file extension    
for root, dirs, files in os.walk(image_folder):
    for file in files:
        filename = os.path.splitext(file)[0] # get filename without extension
        if filename in exclude_list:
            image_path = os.path.join(root, file)
            print('The image has been deleted:', image_path)
            os.remove(image_path)
# Out:
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_080533_0.jpg
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_080533_0.txt
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_082148_0.jpg
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_082148_0.txt
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_085011_0.jpg
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_085011_0.txt
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_091424_0.jpg
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_091424_0.txt
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_140903_0.jpg
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_140903_0.txt
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_141724_0.jpg
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_141724_0.txt
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_142149_0.jpg
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_142149_0.txt
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_142721_0.jpg
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_142721_0.txt
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_143147_0.jpg
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_143147_0.txt
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_143704_0.jpg
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_143704_0.txt
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_144335_0.jpg
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_144335_0.txt
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_144928_0.jpg
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_144928_0.txt
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_145355_0.jpg
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_145355_0.txt
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_145745_0.jpg
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_145745_0.txt
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_150520_0.jpg
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\left1_230310_150520_0.txt
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\right1_230310_075818_0.jpg
# The image has been deleted: //schoolnas-work/schoolnas-work/seatbelt/seatbelt_label_03_06_added_230324_train_data/10_jj_230310_carnival\right1_230310_075818_0.txt
